# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 607

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hamilton
# Processing Record 2 of Set 1 | san jose village
# City not found. Skipping...
# Processing Record 3 of Set 1 | ust-nera
# Processing Record 4 of Set 1 | al kharijah
# Processing Record 5 of Set 1 | tefe
# Processing Record 6 of Set 1 | iwaki
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | kerikeri
# Processing Record 9 of Set 1 | udachny
# Processing Record 10 of Set 1 | garoowe
# Processing Record 11 of Set 1 | tangalle
# Processing Record 12 of Set 1 | vadso
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | nagqu
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | college
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | maydanshakhr
# Processing Record 19 of Set 1 | olonkinbyen
# Processing Record 20 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 21 of Set 1 | loa janan
# Processing Record 22 of Set 1 | newman
# Processing Record 23 of Set 1 | choyr
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | general villegas
# Processing Record 26 of Set 1 | ujae
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | fiambala
# Processing Record 29 of Set 1 | tabou
# Processing Record 30 of Set 1 | northam
# Processing Record 31 of Set 1 | papatowai
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | port-aux-francais
# Processing Record 34 of Set 1 | adamstown
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | hawaiian paradise park
# Processing Record 37 of Set 1 | invercargill
# Processing Record 38 of Set 1 | tolanaro
# Processing Record 39 of Set 1 | bonthe
# Processing Record 40 of Set 1 | chonchi
# Processing Record 41 of Set 1 | queenstown
# Processing Record 42 of Set 1 | preobrazheniye
# Processing Record 43 of Set 1 | puerto natales
# Processing Record 44 of Set 1 | walvis bay
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | blackmans bay
# Processing Record 47 of Set 1 | naliya
# Processing Record 48 of Set 1 | damghan
# Processing Record 49 of Set 1 | susuman
# Processing Record 50 of Set 1 | port mathurin
# Processing Record 0 of Set 2 | fale old settlement
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | la cruz
# Processing Record 3 of Set 2 | talnakh
# Processing Record 4 of Set 2 | aykhal
# Processing Record 5 of Set 2 | bilibino
# Processing Record 6 of Set 2 | nemuro
# Processing Record 7 of Set 2 | bilokurakyne
# Processing Record 8 of Set 2 | stanley
# Processing Record 9 of Set 2 | medina
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | sola
# Processing Record 12 of Set 2 | bor
# Processing Record 13 of Set 2 | birzebbuga
# Processing Record 14 of Set 2 | grytviken
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | pont rouge
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | al faw
# Processing Record 21 of Set 2 | howrah
# Processing Record 22 of Set 2 | panaba
# Processing Record 23 of Set 2 | jining
# Processing Record 24 of Set 2 | santa marta
# Processing Record 25 of Set 2 | crane
# Processing Record 26 of Set 2 | fort stockton
# Processing Record 27 of Set 2 | middelharnis
# Processing Record 28 of Set 2 | port macquarie
# Processing Record 29 of Set 2 | uturoa
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | san antonio de pale
# Processing Record 32 of Set 2 | zhanaozen
# Processing Record 33 of Set 2 | thompson
# Processing Record 34 of Set 2 | pariaman
# Processing Record 35 of Set 2 | qaqortoq
# Processing Record 36 of Set 2 | hadibu
# Processing Record 37 of Set 2 | tobelo
# Processing Record 38 of Set 2 | ndelele
# Processing Record 39 of Set 2 | suva
# Processing Record 40 of Set 2 | remire-montjoly
# Processing Record 41 of Set 2 | khandyga
# Processing Record 42 of Set 2 | ushuaia
# Processing Record 43 of Set 2 | bubaque
# Processing Record 44 of Set 2 | meadow lake
# Processing Record 45 of Set 2 | san fernando de monte cristi
# Processing Record 46 of Set 2 | isangel
# Processing Record 47 of Set 2 | iquitos
# Processing Record 48 of Set 2 | west island
# Processing Record 49 of Set 2 | valley east
# City not found. Skipping...
# Processing Record 0 of Set 3 | nedryhayliv
# Processing Record 1 of Set 3 | wailua homesteads
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | alofi
# Processing Record 4 of Set 3 | vilyuysk
# Processing Record 5 of Set 3 | waddan
# Processing Record 6 of Set 3 | hobe sound
# Processing Record 7 of Set 3 | tazovsky
# Processing Record 8 of Set 3 | kailua-kona
# Processing Record 9 of Set 3 | inarajan village
# Processing Record 10 of Set 3 | dawei
# Processing Record 11 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 12 of Set 3 | whitehorse
# Processing Record 13 of Set 3 | tura
# Processing Record 14 of Set 3 | flying fish cove
# Processing Record 15 of Set 3 | kristiansund
# Processing Record 16 of Set 3 | vashkivtsi
# Processing Record 17 of Set 3 | inhambane
# Processing Record 18 of Set 3 | iskateley
# Processing Record 19 of Set 3 | atafu village
# Processing Record 20 of Set 3 | cleveland
# Processing Record 21 of Set 3 | westport
# Processing Record 22 of Set 3 | isafjordur
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | lazaro cardenas
# Processing Record 27 of Set 3 | kapuskasing
# Processing Record 28 of Set 3 | al hayy
# Processing Record 29 of Set 3 | margaret river
# Processing Record 30 of Set 3 | umuarama
# Processing Record 31 of Set 3 | nuuk
# Processing Record 32 of Set 3 | weno
# Processing Record 33 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 34 of Set 3 | aasiaat
# Processing Record 35 of Set 3 | papao
# Processing Record 36 of Set 3 | chinchilla
# Processing Record 37 of Set 3 | bel ombre
# Processing Record 38 of Set 3 | al bawiti
# Processing Record 39 of Set 3 | vohipaho
# City not found. Skipping...
# Processing Record 40 of Set 3 | vilyuchinsk
# Processing Record 41 of Set 3 | kencong
# Processing Record 42 of Set 3 | tsiombe
# Processing Record 43 of Set 3 | kedrovyy
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | ulsteinvik
# Processing Record 46 of Set 3 | leava
# Processing Record 47 of Set 3 | poronaysk
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | conception bay south
# Processing Record 0 of Set 4 | anna regina
# Processing Record 1 of Set 4 | leh
# Processing Record 2 of Set 4 | enewetak
# Processing Record 3 of Set 4 | badger
# Processing Record 4 of Set 4 | christchurch
# Processing Record 5 of Set 4 | lumut
# Processing Record 6 of Set 4 | akjoujt
# Processing Record 7 of Set 4 | prestea
# Processing Record 8 of Set 4 | sombrerete
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | boke
# Processing Record 11 of Set 4 | fang
# Processing Record 12 of Set 4 | st. john's
# Processing Record 13 of Set 4 | kavaratti
# Processing Record 14 of Set 4 | guymon
# Processing Record 15 of Set 4 | tosontsengel
# Processing Record 16 of Set 4 | dongkan
# Processing Record 17 of Set 4 | keflavik
# Processing Record 18 of Set 4 | afaahiti
# Processing Record 19 of Set 4 | okhotsk
# Processing Record 20 of Set 4 | ghanzi
# Processing Record 21 of Set 4 | little cayman
# City not found. Skipping...
# Processing Record 22 of Set 4 | bao loc
# City not found. Skipping...
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | qarazhal
# Processing Record 25 of Set 4 | amahai
# Processing Record 26 of Set 4 | menongue
# Processing Record 27 of Set 4 | kotlas
# Processing Record 28 of Set 4 | ceeldheer
# Processing Record 29 of Set 4 | sim
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | tahe
# Processing Record 32 of Set 4 | zielona gora
# Processing Record 33 of Set 4 | harstad
# Processing Record 34 of Set 4 | mahibadhoo
# Processing Record 35 of Set 4 | mendi
# Processing Record 36 of Set 4 | chunskiy
# Processing Record 37 of Set 4 | hithadhoo
# Processing Record 38 of Set 4 | parral
# Processing Record 39 of Set 4 | utrik
# Processing Record 40 of Set 4 | buckie
# Processing Record 41 of Set 4 | fort mcmurray
# Processing Record 42 of Set 4 | kurchatov
# Processing Record 43 of Set 4 | calchaqui
# Processing Record 44 of Set 4 | ixtapa
# Processing Record 45 of Set 4 | kayangel
# Processing Record 46 of Set 4 | senador jose porfirio
# Processing Record 47 of Set 4 | jijel
# Processing Record 48 of Set 4 | aldinga beach
# Processing Record 49 of Set 4 | princeville
# Processing Record 0 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | kolonia town
# Processing Record 4 of Set 5 | marudi
# City not found. Skipping...
# Processing Record 5 of Set 5 | hoxtolgay
# City not found. Skipping...
# Processing Record 6 of Set 5 | callao
# Processing Record 7 of Set 5 | cockburn town
# Processing Record 8 of Set 5 | tres arroyos
# Processing Record 9 of Set 5 | taroa
# Processing Record 10 of Set 5 | north bend
# Processing Record 11 of Set 5 | port douglas
# Processing Record 12 of Set 5 | murzuq
# Processing Record 13 of Set 5 | vega de alatorre
# Processing Record 14 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 15 of Set 5 | weihai
# Processing Record 16 of Set 5 | abu qurqas
# Processing Record 17 of Set 5 | lichinga
# Processing Record 18 of Set 5 | flin flon
# Processing Record 19 of Set 5 | grand falls-windsor
# Processing Record 20 of Set 5 | kiunga
# Processing Record 21 of Set 5 | bishunpur urf maharajganj
# Processing Record 22 of Set 5 | nikolayevsk-on-amure
# Processing Record 23 of Set 5 | lihue
# Processing Record 24 of Set 5 | anadyr
# Processing Record 25 of Set 5 | mundybash
# Processing Record 26 of Set 5 | coahuayana de hidalgo
# Processing Record 27 of Set 5 | arenapolis
# Processing Record 28 of Set 5 | zhangye
# Processing Record 29 of Set 5 | gamba
# Processing Record 30 of Set 5 | kourou
# Processing Record 31 of Set 5 | lerida
# Processing Record 32 of Set 5 | sydney mines
# Processing Record 33 of Set 5 | mukalla
# Processing Record 34 of Set 5 | roma
# Processing Record 35 of Set 5 | tadine
# Processing Record 36 of Set 5 | gueltat zemmour
# City not found. Skipping...
# Processing Record 37 of Set 5 | bakchar
# Processing Record 38 of Set 5 | spring creek
# Processing Record 39 of Set 5 | lagunas
# Processing Record 40 of Set 5 | tshabong
# Processing Record 41 of Set 5 | mhamid
# Processing Record 42 of Set 5 | videira
# Processing Record 43 of Set 5 | camarinas
# Processing Record 44 of Set 5 | graham
# Processing Record 45 of Set 5 | choibalsan
# Processing Record 46 of Set 5 | shingu
# Processing Record 47 of Set 5 | xinqing
# Processing Record 48 of Set 5 | onil
# Processing Record 49 of Set 5 | sao joao da barra
# Processing Record 0 of Set 6 | inekar
# City not found. Skipping...
# Processing Record 1 of Set 6 | severn
# Processing Record 2 of Set 6 | salekhard
# Processing Record 3 of Set 6 | yuzhno-kurilsk
# Processing Record 4 of Set 6 | whakatane
# Processing Record 5 of Set 6 | voi
# Processing Record 6 of Set 6 | gerash
# Processing Record 7 of Set 6 | guerrero negro
# Processing Record 8 of Set 6 | phan rang-thap cham
# Processing Record 9 of Set 6 | tsiroanomandidy
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | nadym
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | rio grande
# Processing Record 14 of Set 6 | vorgashor
# Processing Record 15 of Set 6 | thurso
# Processing Record 16 of Set 6 | vail
# Processing Record 17 of Set 6 | raduzhnyy
# Processing Record 18 of Set 6 | sainte-marie
# Processing Record 19 of Set 6 | kuanda
# Processing Record 20 of Set 6 | kijang
# Processing Record 21 of Set 6 | tokar
# Processing Record 22 of Set 6 | rawson
# Processing Record 23 of Set 6 | darwin
# Processing Record 24 of Set 6 | el salto
# Processing Record 25 of Set 6 | lashio
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | holualoa
# Processing Record 28 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 6 | cedeira
# Processing Record 30 of Set 6 | fernley
# Processing Record 31 of Set 6 | san luis de la loma
# Processing Record 32 of Set 6 | arraial do cabo
# Processing Record 33 of Set 6 | floro
# Processing Record 34 of Set 6 | luwuk
# Processing Record 35 of Set 6 | hassi messaoud
# Processing Record 36 of Set 6 | gaoual
# Processing Record 37 of Set 6 | tevriz
# Processing Record 38 of Set 6 | nar'yan-mar
# Processing Record 39 of Set 6 | pitimbu
# Processing Record 40 of Set 6 | tamanrasset
# Processing Record 41 of Set 6 | manta
# Processing Record 42 of Set 6 | kotido
# Processing Record 43 of Set 6 | manga
# Processing Record 44 of Set 6 | nova sintra
# Processing Record 45 of Set 6 | sebastopol
# Processing Record 46 of Set 6 | egersund
# Processing Record 47 of Set 6 | la passe
# Processing Record 48 of Set 6 | lesnoy
# Processing Record 49 of Set 6 | constantia
# Processing Record 0 of Set 7 | qarauyl
# Processing Record 1 of Set 7 | ciudad madero
# Processing Record 2 of Set 7 | alma
# Processing Record 3 of Set 7 | sitka
# Processing Record 4 of Set 7 | luderitz
# Processing Record 5 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 6 of Set 7 | kununurra
# Processing Record 7 of Set 7 | magadan
# Processing Record 8 of Set 7 | fort st. john
# Processing Record 9 of Set 7 | basoko
# Processing Record 10 of Set 7 | kaiapoi
# Processing Record 11 of Set 7 | horta
# Processing Record 12 of Set 7 | mon
# Processing Record 13 of Set 7 | sonoita
# Processing Record 14 of Set 7 | zhosaly
# Processing Record 15 of Set 7 | las heras
# Processing Record 16 of Set 7 | klyuchi
# Processing Record 17 of Set 7 | san andres
# Processing Record 18 of Set 7 | shenjiamen
# Processing Record 19 of Set 7 | mukah
# City not found. Skipping...
# Processing Record 20 of Set 7 | batticaloa
# Processing Record 21 of Set 7 | sherpur
# Processing Record 22 of Set 7 | upington
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | tual
# Processing Record 25 of Set 7 | ad dabbah
# Processing Record 26 of Set 7 | villa de cos
# Processing Record 27 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 28 of Set 7 | margate
# Processing Record 29 of Set 7 | saldanha
# Processing Record 30 of Set 7 | revda
# Processing Record 31 of Set 7 | mingguang
# Processing Record 32 of Set 7 | mogocha
# Processing Record 33 of Set 7 | funafuti
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | iquique
# Processing Record 36 of Set 7 | piacabucu
# Processing Record 37 of Set 7 | mili
# Processing Record 38 of Set 7 | vila velha
# Processing Record 39 of Set 7 | soio
# Processing Record 40 of Set 7 | morondava
# Processing Record 41 of Set 7 | daru
# Processing Record 42 of Set 7 | alesund
# Processing Record 43 of Set 7 | laayoune plage
# City not found. Skipping...
# Processing Record 44 of Set 7 | colonia
# Processing Record 45 of Set 7 | san ignacio de velasco
# Processing Record 46 of Set 7 | coquimbo
# Processing Record 47 of Set 7 | igarka
# Processing Record 48 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 7 | gadzhiyevo
# Processing Record 0 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 1 of Set 8 | zherdevka
# Processing Record 2 of Set 8 | saudarkrokur
# Processing Record 3 of Set 8 | gisborne
# Processing Record 4 of Set 8 | amos
# Processing Record 5 of Set 8 | polyarnyy
# Processing Record 6 of Set 8 | bolgar
# Processing Record 7 of Set 8 | port alfred
# Processing Record 8 of Set 8 | shatrovo
# Processing Record 9 of Set 8 | puerto armuelles
# Processing Record 10 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 11 of Set 8 | wanning
# Processing Record 12 of Set 8 | lucapa
# Processing Record 13 of Set 8 | mbuji-mayi
# Processing Record 14 of Set 8 | amurzet
# Processing Record 15 of Set 8 | itoman
# Processing Record 16 of Set 8 | at tall al kabir
# Processing Record 17 of Set 8 | nueva villa de padilla
# Processing Record 18 of Set 8 | mount pearl
# Processing Record 19 of Set 8 | fehrbellin
# Processing Record 20 of Set 8 | portland
# Processing Record 21 of Set 8 | askoy
# Processing Record 22 of Set 8 | labytnangi
# Processing Record 23 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 8 | bikenibeu village
# Processing Record 25 of Set 8 | bamboo flat
# Processing Record 26 of Set 8 | bayanhongor
# Processing Record 27 of Set 8 | tuscania
# Processing Record 28 of Set 8 | mitu
# Processing Record 29 of Set 8 | la sarre
# Processing Record 30 of Set 8 | fortuna
# Processing Record 31 of Set 8 | robertsport
# Processing Record 32 of Set 8 | tank
# Processing Record 33 of Set 8 | vangaindrano
# Processing Record 34 of Set 8 | tiznit
# Processing Record 35 of Set 8 | kopong
# Processing Record 36 of Set 8 | kudahuvadhoo
# Processing Record 37 of Set 8 | cole harbour
# Processing Record 38 of Set 8 | kill devil hills
# Processing Record 39 of Set 8 | topolobampo
# Processing Record 40 of Set 8 | alegrete
# Processing Record 41 of Set 8 | kidal
# Processing Record 42 of Set 8 | dadonghai
# City not found. Skipping...
# Processing Record 43 of Set 8 | tagiura
# Processing Record 44 of Set 8 | kulhudhuffushi
# Processing Record 45 of Set 8 | saipan
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | mil'kovo
# Processing Record 48 of Set 8 | andalgala
# Processing Record 49 of Set 8 | nouna
# Processing Record 0 of Set 9 | teguise
# Processing Record 1 of Set 9 | luganville
# Processing Record 2 of Set 9 | kalabo
# Processing Record 3 of Set 9 | gizo
# Processing Record 4 of Set 9 | alice springs
# Processing Record 5 of Set 9 | turpan
# Processing Record 6 of Set 9 | piton saint-leu
# Processing Record 7 of Set 9 | richfield
# Processing Record 8 of Set 9 | ambovombe
# Processing Record 9 of Set 9 | songkhla
# Processing Record 10 of Set 9 | chusovoy
# Processing Record 11 of Set 9 | fox lake
# Processing Record 12 of Set 9 | nikolayevka
# Processing Record 13 of Set 9 | la'ie
# Processing Record 14 of Set 9 | erdemli
# Processing Record 15 of Set 9 | hinton
# Processing Record 16 of Set 9 | wajir
# Processing Record 17 of Set 9 | rikaze
# Processing Record 18 of Set 9 | lucea
# Processing Record 19 of Set 9 | dampit
# Processing Record 20 of Set 9 | abepura
# Processing Record 21 of Set 9 | singleton
# Processing Record 22 of Set 9 | petropavlovka
# Processing Record 23 of Set 9 | zavetnoye
# Processing Record 24 of Set 9 | talara
# Processing Record 25 of Set 9 | inzhavino
# Processing Record 26 of Set 9 | egilsstadir
# Processing Record 27 of Set 9 | batangafo
# Processing Record 28 of Set 9 | koryukivka
# Processing Record 29 of Set 9 | hoemul-li
# Processing Record 30 of Set 9 | mahabe
# City not found. Skipping...
# Processing Record 31 of Set 9 | san jose del guaviare
# Processing Record 32 of Set 9 | peniche
# Processing Record 33 of Set 9 | sandnessjoen
# Processing Record 34 of Set 9 | yanam
# Processing Record 35 of Set 9 | coracora
# Processing Record 36 of Set 9 | kabinda
# Processing Record 37 of Set 9 | namibe
# Processing Record 38 of Set 9 | fort william
# Processing Record 39 of Set 9 | kingston
# Processing Record 40 of Set 9 | borogontsy
# Processing Record 41 of Set 9 | basse-terre
# Processing Record 42 of Set 9 | antofagasta
# Processing Record 43 of Set 9 | delaware
# Processing Record 44 of Set 9 | san patricio
# Processing Record 45 of Set 9 | berbera
# Processing Record 46 of Set 9 | lensk
# Processing Record 47 of Set 9 | shahrud
# Processing Record 48 of Set 9 | san buenaventura
# Processing Record 49 of Set 9 | palikir - national government center
# Processing Record 0 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 1 of Set 10 | warm mineral springs
# Processing Record 2 of Set 10 | trumann
# Processing Record 3 of Set 10 | divrigi
# Processing Record 4 of Set 10 | kavieng
# Processing Record 5 of Set 10 | mandera
# Processing Record 6 of Set 10 | sabang
# Processing Record 7 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 8 of Set 10 | malango
# Processing Record 9 of Set 10 | gakem
# Processing Record 10 of Set 10 | hopelchen
# Processing Record 11 of Set 10 | kruisfontein
# Processing Record 12 of Set 10 | smithers
# Processing Record 13 of Set 10 | mudgee
# Processing Record 14 of Set 10 | san ramon de la nueva oran
# Processing Record 15 of Set 10 | imbituba
# Processing Record 16 of Set 10 | liupanshui
# City not found. Skipping...
# Processing Record 17 of Set 10 | wagini
# Processing Record 18 of Set 10 | kara
# Processing Record 19 of Set 10 | dryden
# Processing Record 20 of Set 10 | pasni
# Processing Record 21 of Set 10 | nguigmi
# Processing Record 22 of Set 10 | pangody
# Processing Record 23 of Set 10 | catalca
# Processing Record 24 of Set 10 | sitangkai
# Processing Record 25 of Set 10 | pushkinskiye gory
# Processing Record 26 of Set 10 | hotan
# Processing Record 27 of Set 10 | vanino
# Processing Record 28 of Set 10 | tralee
# Processing Record 29 of Set 10 | uren'
# Processing Record 30 of Set 10 | nelson
# Processing Record 31 of Set 10 | bengkulu
# Processing Record 32 of Set 10 | mingshui
# Processing Record 33 of Set 10 | scalea
# Processing Record 34 of Set 10 | acapulco de juarez
# Processing Record 35 of Set 10 | mikkeli
# Processing Record 36 of Set 10 | margherita
# Processing Record 37 of Set 10 | rizhao
# Processing Record 38 of Set 10 | eyl
# Processing Record 39 of Set 10 | jelgava
# Processing Record 40 of Set 10 | mwene-ditu
# Processing Record 41 of Set 10 | bodo
# Processing Record 42 of Set 10 | keetmanshoop
# Processing Record 43 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 44 of Set 10 | fort bragg
# Processing Record 45 of Set 10 | alamos
# Processing Record 46 of Set 10 | kapoeta
# Processing Record 47 of Set 10 | druskininkai
# Processing Record 48 of Set 10 | hualien city
# Processing Record 49 of Set 10 | kirakira
# Processing Record 0 of Set 11 | onokhoy
# Processing Record 1 of Set 11 | bizerte
# Processing Record 2 of Set 11 | divnoye
# Processing Record 3 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 4 of Set 11 | hammerfest
# Processing Record 5 of Set 11 | harper
# Processing Record 6 of Set 11 | pamandzi
# Processing Record 7 of Set 11 | hobyo
# Processing Record 8 of Set 11 | betio village
# Processing Record 9 of Set 11 | alvear
# Processing Record 10 of Set 11 | mugia
# Processing Record 11 of Set 11 | bulayevo
# Processing Record 12 of Set 11 | chernyshevskiy
# Processing Record 13 of Set 11 | itauna
# Processing Record 14 of Set 11 | boguchany
# Processing Record 15 of Set 11 | east london
# Processing Record 16 of Set 11 | al bayda'
# Processing Record 17 of Set 11 | guarapari
# Processing Record 18 of Set 11 | okakarara
# Processing Record 19 of Set 11 | berezovyy
# Processing Record 20 of Set 11 | ust'-ordynskiy
# Processing Record 21 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 22 of Set 11 | antalaha
# Processing Record 23 of Set 11 | breckenridge
# Processing Record 24 of Set 11 | sinabang
# Processing Record 25 of Set 11 | vordingborg
# Processing Record 26 of Set 11 | ngawi
# Processing Record 27 of Set 11 | oberammergau
# Processing Record 28 of Set 11 | nuku'alofa
# Processing Record 29 of Set 11 | byron bay
# Processing Record 30 of Set 11 | cidreira
# Processing Record 31 of Set 11 | chizhou
# Processing Record 32 of Set 11 | north battleford
# Processing Record 33 of Set 11 | asau
# Processing Record 34 of Set 11 | zhezqazghan
# Processing Record 35 of Set 11 | buala
# Processing Record 36 of Set 11 | vangviang
# Processing Record 37 of Set 11 | ciudad constitucion
# Processing Record 38 of Set 11 | mount gambier
# Processing Record 39 of Set 11 | oriximina
# Processing Record 40 of Set 11 | constitucion
# Processing Record 41 of Set 11 | jiuquan
# Processing Record 42 of Set 11 | mahalapye
# Processing Record 43 of Set 11 | susanville
# Processing Record 44 of Set 11 | madanapalle
# Processing Record 45 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 46 of Set 11 | luanco
# Processing Record 47 of Set 11 | san fernando de apure
# Processing Record 48 of Set 11 | katsuura
# Processing Record 49 of Set 11 | quatre cocos
# Processing Record 0 of Set 12 | kadhan
# Processing Record 1 of Set 12 | carnarvon
# Processing Record 2 of Set 12 | mocajuba
# Processing Record 3 of Set 12 | flekkefjord
# Processing Record 4 of Set 12 | stalbe
# Processing Record 5 of Set 12 | vorkuta
# Processing Record 6 of Set 12 | barrinha
# Processing Record 7 of Set 12 | burang
# Processing Record 8 of Set 12 | padang
# Processing Record 9 of Set 12 | stephenville
# Processing Record 10 of Set 12 | novo aripuana
# Processing Record 11 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 12 of Set 12 | mirnyy
# Processing Record 13 of Set 12 | lubuklinggau
# Processing Record 14 of Set 12 | sao tome
# Processing Record 15 of Set 12 | new norfolk
# Processing Record 16 of Set 12 | moree
# Processing Record 17 of Set 12 | zaraza
# Processing Record 18 of Set 12 | springbok
# Processing Record 19 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 20 of Set 12 | dudinka
# Processing Record 21 of Set 12 | tofol
# Processing Record 22 of Set 12 | jinghong
# Processing Record 23 of Set 12 | calca
# Processing Record 24 of Set 12 | wang sai phun
# Processing Record 25 of Set 12 | ranau
# Processing Record 26 of Set 12 | al kharj
# Processing Record 27 of Set 12 | dombarovskiy
# Processing Record 28 of Set 12 | iida
# Processing Record 29 of Set 12 | justo daract
# Processing Record 30 of Set 12 | stanytsya luhans'ka
# City not found. Skipping...
# Processing Record 31 of Set 12 | bantay
# Processing Record 32 of Set 12 | torres
# Processing Record 33 of Set 12 | mao
# Processing Record 34 of Set 12 | akureyri
# Processing Record 35 of Set 12 | cowra
# Processing Record 36 of Set 12 | midvagur
# Processing Record 37 of Set 12 | baise city
# Processing Record 38 of Set 12 | cumbal
# Processing Record 39 of Set 12 | kohima
# Processing Record 40 of Set 12 | bude
# Processing Record 41 of Set 12 | taman'
# Processing Record 42 of Set 12 | pisco
# Processing Record 43 of Set 12 | rehoboth
# Processing Record 44 of Set 12 | pau brasil
# Processing Record 45 of Set 12 | beyneu
# Processing Record 46 of Set 12 | kurumkan
# Processing Record 47 of Set 12 | wimborne minster
# Processing Record 48 of Set 12 | laguna
# Processing Record 49 of Set 12 | puerto baquerizo moreno
# Processing Record 0 of Set 13 | nova vicosa
# Processing Record 1 of Set 13 | necochea
# Processing Record 2 of Set 13 | yashkul'
# Processing Record 3 of Set 13 | rudbar
# Processing Record 4 of Set 13 | cerro de ortega
# Processing Record 5 of Set 13 | hancheng
# Processing Record 6 of Set 13 | port augusta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     hamilton  39.1834  -84.5333     25.87        81           0        5.14
# 1     ust-nera  64.5667  143.2000     18.89        54         100        1.36
# 2  al kharijah  25.4514   30.5464     37.41        10          26        1.66
# 3         tefe  -3.3542  -64.7114     22.06        98          93        1.00
# 4        iwaki  37.0500  140.8833     28.76        86         100        2.00
#
#   Country        Date
# 0      US  1719997661
# 1      RU  1719997927
# 2      EG  1719997928
# 3      BR  1719997929
# 4      JP  1719997252

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           hamilton  39.1834  -84.5333     25.87        81           0
# 1           ust-nera  64.5667  143.2000     18.89        54         100
# 2        al kharijah  25.4514   30.5464     37.41        10          26
# 3               tefe  -3.3542  -64.7114     22.06        98          93
# 4              iwaki  37.0500  140.8833     28.76        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1719997661
# 1              1.36      RU  1719997927
# 2              1.66      EG  1719997928
# 3              1.00      BR  1719997929
# 4              2.00      JP  1719997252

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2024-06-17)")
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Max Latitude vs. Humidity (2024-06-17)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Max Latitude vs. Cloudiness (2024-06-17)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs. Wind Speed (2024-06-17)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regressions(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    plt.scatter(x,y)
    plt.plot(x, slope * x + intercept, color='red')
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.annotate(line_eq,(x.min(), y.min()),fontsize=15,color="red")
    print(f"The r^2 value is: {rvalue**2}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           hamilton  39.1834  -84.5333     25.87        81           0
# 1           ust-nera  64.5667  143.2000     18.89        54         100
# 2        al kharijah  25.4514   30.5464     37.41        10          26
# 4              iwaki  37.0500  140.8833     28.76        86         100
# 7            udachny  66.4167  112.4000     16.51        32          17
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1719997661
# 1              1.36      RU  1719997927
# 2              1.66      EG  1719997928
# 4              2.00      JP  1719997252
# 7              7.80      RU  1719997935

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3                               tefe  -3.3542  -64.7114     22.06        98
# 5        edinburgh of the seven seas -37.0676  -12.3116     13.34        79
# 6                           kerikeri -35.2268  173.9474      8.89        84
# 11                          waitangi -43.9535 -176.5597      7.12        97
# 15                            avarua -21.2078 -159.7750     24.03        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                93        1.00      BR  1719997929
# 5                38       17.75      SH  1719997932
# 6                72        1.61      NZ  1719997933
# 11              100        2.68      NZ  1719997940
# 15               20        4.12      CK  1719997946

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regressions(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Latitude Vs. Max Temp")
plt.ylim(-8, 48)
plt.show()
# Out:
# The r^2 value is: 0.301977665104605

# %%
# Linear regression on Southern Hemisphere
plot_linear_regressions(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Latitude Vs. Max Temp")
plt.ylim(-8, 48)
plt.show()
# Out:
# The r^2 value is: 0.702700628992951

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression is modelling the max temperature observed over a random selection of cities by their latitude. It is observed that in the northern hemisphere a strong negative correlation occurs while in the southern hemisphere a slightly stronger correlation is present but in the positive direction. From these results, in the norther hemisphere is can be generally concluded that the lower the latitude, the higher the temperature. In the southern hemisphere the opposite is true, the lower the latitude, the lower the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regressions(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude Vs. Humidity")
plt.show()
# Out:
# The r^2 value is: 0.007478447192482908

# %%
# Southern Hemisphere
plot_linear_regressions(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitude Vs. Humidity")
plt.show()
# Out:
# The r^2 value is: 0.0007168373114202851

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression is modelling the humidity observed over a random selection of cities by their latitude. It is observed that in the northern and southern hemisphere a very weak correlation between latitude and humidity is present as r^2 value for both regressions is below 0.05. The northern hemisphere displays a slightly positive correlation while the southern hemisphere shows a slightly negative correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regressions(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude Vs. Cloudiness")
plt.show()
# Out:
# The r^2 value is: 4.812022018943698e-05

# %%
# Southern Hemisphere
plot_linear_regressions(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitude Vs. Cloudiness")
plt.show()
# Out:
# The r^2 value is: 0.04112244093834064

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression is modelling the cloudiness observed over a random selection of cities by their latitude. It is observed that there is a weak correlation in the negative direction in the northern hemisphere. In the southern hemisphere a very weak positive correlation is seen. This shows that latitudes closer to 0 exhibit slightly more cloudiness than latitudes that are further away from 0.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regressions(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude Vs. Wind Speed")
plt.ylim(-1, 22)
plt.show()
# Out:
# The r^2 value is: 0.003648744672524996

# %%
# Southern Hemisphere
plot_linear_regressions(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude Vs. Wind Speed")
plt.ylim(-1, 22)
plt.show()
# Out:
# The r^2 value is: 0.0027380313528895563

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression is modelling the wind speed observed over a random selection of cities by their latitude. It is observed that in both the northern and southern hemisphere a very weak negative correlation between latitude and wind speed is present as r^2 value for both regressions is below 0.05.
